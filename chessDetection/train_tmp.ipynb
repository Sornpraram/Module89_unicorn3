# %%
import cv2
import os
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import tensorflow as tf

from termcolor import cprint
from yolo_tiny_like_tf.dataset import Dataset
from yolo_tiny_like_tf.yolov3_tiny_model import Create_Yolo, compute_loss
# from yolo_tiny_like_tf.yolov4_tiny_model import Create_Yolo, compute_loss
from yolo_tiny_like_tf.utils import load_yolo_weights, detect_image
from yolo_tiny_like_tf.configs import *

# if MODEL_TYPE == "yolov4":
#     Darknet_weights = YOLO_V4_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V4_WEIGHTS

# Darknet_weights = YOLO_V4_TINY_WEIGHTS

# if MODEL_TYPE == "yolov3":
#     Darknet_weights = YOLO_V3_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V3_WEIGHTS
# if TRAIN_YOLO_TINY: TRAIN_MODEL_NAME += "_Tiny"

def main():
    global TRAIN_FROM_CHECKPOINT
    #====================================== Tensorflow-GPU Detector =======================================

    gpus = tf.config.experimental.list_physical_devices('GPU')
    print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
    
    if len(gpus) > 0:
        
        print("using GPU")
        try: tf.config.experimental.set_memory_growth(gpus[0], True)
        except RuntimeError: pass
    else:
        print("using CPU")

    #====================================== Calculate Training Step ========================================

    trainset = Dataset('train')
    testset = Dataset('test')

    steps_per_epoch = len(trainset) # iterations or num_batch
    print(steps_per_epoch)
    global_steps = tf.Variable(1, trainable=False, dtype=tf.int64) # create tf variable to hold value of global step
    warmup_steps = TRAIN_WARMUP_EPOCHS * steps_per_epoch # 2 * 26 = 52 Stepแรก จะค่อยๆทำการเพิ่ม lr
    total_steps = TRAIN_EPOCHS * steps_per_epoch

    #============================ Create Model & Load Checpoint & Init Optimizer =========================================

    if TRAIN_TRANSFER:
        if MODEL_TYPE == "yolov4":
            Darknet_weights = YOLO_V4_TINY_WEIGHTS
        elif MODEL_TYPE == "yolov3":
            Darknet_weights = YOLO_V3_TINY_WEIGHTS

        print(Darknet_weights)
        Darknet = Create_Yolo(input_size=INPUT_RESOLUTION, CLASSES=YOLO_COCO_CLASSES)
        load_yolo_weights(Darknet, Darknet_weights) # use darknet weights

    yolo = Create_Yolo(input_size=INPUT_RESOLUTION, training=True, CLASSES=TRAIN_CLASSES)

    if TRAIN_FROM_CHECKPOINT:
        try:
            yolo.load_weights(f"./checkpoints/{TRAIN_FROM_CHECKPOINT_NAME}")
            cprint(f"Train from checkpoint >>> {TRAIN_FROM_CHECKPOINT_NAME} ", "green")
        except:
            cprint("Load Checkpoint Error >>> Train from zero instead", "red")

    if TRAIN_TRANSFER and not TRAIN_FROM_CHECKPOINT:
        for i, l in enumerate(Darknet.layers):
            layer_weights = l.get_weights()
            if layer_weights != []:
                try:
                    yolo.layers[i].set_weights(layer_weights)
                    cprint(f"Transfer Learning >>> {YOLO_V4_TINY_WEIGHTS} ", "green")
                except:
                    print("skipping", yolo.layers[i].name)

    if not TRAIN_TRANSFER and not TRAIN_FROM_CHECKPOINT:
        cprint(f"Train from Zero >>> {MODEL_TYPE} ", "blue")

    optimizer = tf.keras.optimizers.Adam()

    # =============================================================== validate step ===================================================================
    
    def train_step(image_data, target):

        with tf.GradientTape() as tape: # ใช้คำนวณ GradiantDesent ของ trainable variable ทุกตัว

            pred_result = yolo(image_data, training=True) # Feed image เข้า Model. # Return
            giou_loss = 0  # loss function ()
            conf_loss = 0  # loss function ()
            prob_loss = 0  # loss function ()

            # optimizing process
            grid = 3 if not TRAIN_YOLO_TINY else 2
            for i in range(grid):
                conv, pred = pred_result[i*2], pred_result[i*2+1]
                loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
                giou_loss += loss_items[0]
                conf_loss += loss_items[1]
                prob_loss += loss_items[2]

            total_loss = giou_loss + conf_loss + prob_loss # ค่า loss total เป็นผลรวมของ loss

            gradients = tape.gradient(total_loss, yolo.trainable_variables) # คำนวณ Gradiant tape.gradient(target, sources) return eagerTensor
            optimizer.apply_gradients(zip(gradients, yolo.trainable_variables))

        # ========================================= update learning rate (warmup algorithm) ============================================

            global_steps.assign_add(1)
            if global_steps < warmup_steps:   # and not TRAIN_TRANSFER:
                lr = global_steps / warmup_steps * TRAIN_LR_INIT   # (global_step) / 52 *  0.0001  # ใน 52 step แรก lr จะค่อยๆเพิ่มขึ้น จากนั้นจะคงที่
            else:
                lr = TRAIN_LR_END + 0.5 * (TRAIN_LR_INIT - TRAIN_LR_END)*(  # 0.000001 + [0.5 * (0.0001 - 0.000001) * some funcking algorithm]
                    (1 + tf.cos((global_steps - warmup_steps) / (total_steps - warmup_steps) * np.pi))) # 0.000001 เซ็ตค่า lr ต่ำสุดที่เป็นไปได้
            optimizer.lr.assign(lr.numpy())
            
        return global_steps.numpy(), optimizer.lr.numpy(), giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()

    # =============================================================== validate step ===================================================================

    def validate_step(image_data, target):
        with tf.GradientTape() as tape:
            pred_result = yolo(image_data, training=False)
            giou_loss=conf_loss=prob_loss=0

            # optimizing process
            grid = 3 if not TRAIN_YOLO_TINY else 2
            for i in range(grid):
                conv, pred = pred_result[i*2], pred_result[i*2+1]
                loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
                giou_loss += loss_items[0]
                conf_loss += loss_items[1]
                prob_loss += loss_items[2]

            total_loss = giou_loss + conf_loss + prob_loss
            
        return giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()

    # mAP_model = Create_Yolo(input_size=INPUT_RESOLUTION, CLASSES=TRAIN_CLASSES) # create second model to measure mAP

    # ============================================================== Start Training =======================================================

    best_val_loss = 1000  # เอาไว้เทียบค่า val loss ตอนเซฟ best model
    for epoch in range(TRAIN_EPOCHS):

        # ======================================================= Train each epoch ========================================================

        for image_data, target in trainset:  # Loop over train step (Num Batch)
            results = train_step(image_data, target) # return global_steps, optimizer.lr, giou_loss, conf_loss, prob_loss, total_loss
            cur_step = results[0] % steps_per_epoch  # เศษของ Global step หาร num batch จะได้ Current step ของ Epoch นั้นๆ

            # print(global_steps)
            # print(results[0])

            cprint("epoch:{:2.0f} step:{:5.0f}/{}, lr:{:.6f}, giou_loss:{:7.2f}, conf_loss:{:7.2f}, prob_loss:{:7.2f}, total_loss:{:7.2f}"
                .format(epoch, cur_step, steps_per_epoch, results[1], results[2], results[3], results[4], results[5]), "yellow")
        
        # ====================================================== Validate valid set =======================================================

        count, giou_val, conf_val, prob_val, total_val = 0., 0, 0, 0, 0
        for image_data, target in testset:
            results = validate_step(image_data, target) # return giou_loss, conf_loss, prob_loss, total_loss
            count += 1  # จำนวนใน validation set
            giou_val += results[0] 
            conf_val += results[1]
            prob_val += results[2]
            total_val += results[3]
        # ========================================================= End Validation ========================================================
            
        cprint("\n\ngiou_val_loss:{:7.2f}, conf_val_loss:{:7.2f}, prob_val_loss:{:7.2f}, total_val_loss:{:7.2f}\n\n".
            format(giou_val/count, conf_val/count, prob_val/count, total_val/count), "green")

        # ================================================== Save Checkpoint =================================================

        if TRAIN_SAVE_CHECKPOINT:
            save_directory = os.path.join(TRAIN_CHECKPOINTS_FOLDER, TRAIN_MODEL_NAME+"_loss_{:.2f}".format(total_val/count))+"_epoch_{}".format(epoch)
            yolo.save_weights(save_directory)
        if TRAIN_SAVE_BEST and best_val_loss>total_val/count:
            save_directory = os.path.join(TRAIN_CHECKPOINTS_FOLDER, TRAIN_MODEL_NAME+"_best")
            yolo.save_weights(save_directory)
            best_val_loss = total_val/count

# =============================================================================================================================

if __name__ == '__main__':
    main()
# Out:
# Num GPUs Available:  0
# using CPU
# 51
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 416, 416, 16) 432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 416, 416, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 416, 416, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 208, 208, 16) 0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 208, 208, 32) 4608        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 208, 208, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 208, 208, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 104, 104, 32) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 104, 104, 64) 18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 104, 104, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 104, 104, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 52, 52, 64)   0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 52, 52, 128)  73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 52, 52, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 52, 52, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 128)  0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 26, 26, 256)  294912      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 26, 26, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 26, 26, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 13, 13, 256)  0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 13, 13, 512)  1179648     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 13, 13, 512)  2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 13, 13, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 512)  0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 13, 13, 1024) 4718592     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 13, 13, 1024) 4096        conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 13, 13, 1024) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 13, 13, 256)  262144      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 13, 13, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 13, 13, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 13, 13, 128)  32768       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 13, 13, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 13, 13, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ResizeNearestNeighb [(None, 26, 26, 128) 0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 26, 26, 384) 0           tf_op_layer_ResizeNearestNeighbor
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 26, 26, 256)  884736      tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 13, 13, 512)  1179648     leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 26, 26, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 13, 13, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 26, 26, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 13, 13, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 26, 26, 54)   13878       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 13, 13, 54)   27702       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape (TensorFlowOp [(4,)]               0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_1 (TensorFlow [(4,)]               0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_3 (Te [()]                 0           tf_op_layer_Shape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range (TensorFlowOp [(None,)]            0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_1 (TensorFlow [(None,)]            0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_2 (TensorFlow [(None,)]            0           tf_op_layer_strided_slice_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_3 (TensorFlow [(None,)]            0           tf_op_layer_strided_slice_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_1 (TensorFlowO [()]                 0           tf_op_layer_Range_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size (TensorFlowOpL [()]                 0           tf_op_layer_Range[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_3 (TensorFlowO [()]                 0           tf_op_layer_Range_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_2 (TensorFlowO [()]                 0           tf_op_layer_Range_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_1 (TensorFl [(None, 1)]          0           tf_op_layer_Range[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_packed (TensorFlowO [(2,)]               0           tf_op_layer_Size_1[0][0]
#                                                                  tf_op_layer_Size[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_2 (TensorFl [(1, None)]          0           tf_op_layer_Range_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_6 (TensorFl [(None, 1)]          0           tf_op_layer_Range_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_packed_1 (TensorFlo [(2,)]               0           tf_op_layer_Size_3[0][0]
#                                                                  tf_op_layer_Size_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_7 (TensorFl [(1, None)]          0           tf_op_layer_Range_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_3 (TensorFl [(1, None)]          0           tf_op_layer_Reshape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Fill (TensorFlowOpL [(None, None)]       0           tf_op_layer_packed[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_4 (TensorFl [(None, 1)]          0           tf_op_layer_Reshape_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_8 (TensorFl [(1, None)]          0           tf_op_layer_Reshape_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Fill_1 (TensorFlowO [(None, None)]       0           tf_op_layer_packed_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_9 (TensorFl [(None, 1)]          0           tf_op_layer_Reshape_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, None)]       0           tf_op_layer_Reshape_3[0][0]
#                                                                  tf_op_layer_Fill[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None, None)]       0           tf_op_layer_Reshape_4[0][0]
#                                                                  tf_op_layer_Fill[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_5 (TensorFlowOp [(None, None)]       0           tf_op_layer_Reshape_8[0][0]
#                                                                  tf_op_layer_Fill_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_6 (TensorFlowOp [(None, None)]       0           tf_op_layer_Reshape_9[0][0]
#                                                                  tf_op_layer_Fill_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [()]                 0           tf_op_layer_Shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack (TensorFlowOp [(None, None, 2)]    0           tf_op_layer_Mul[0][0]
#                                                                  tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [()]                 0           tf_op_layer_Shape_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_1 (TensorFlow [(None, None, 2)]    0           tf_op_layer_Mul_5[0][0]
#                                                                  tf_op_layer_Mul_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape/shape (Tens [(5,)]               0           tf_op_layer_strided_slice[0][0]
#                                                                  tf_op_layer_strided_slice_1[0][0]
#                                                                  tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(None, None, 1, 2)] 0           tf_op_layer_stack[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_5/shape (Te [(5,)]               0           tf_op_layer_strided_slice_2[0][0]
#                                                                  tf_op_layer_strided_slice_3[0][0]
#                                                                  tf_op_layer_strided_slice_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_2 (Tenso [(None, None, 1, 2)] 0           tf_op_layer_stack_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, None, None,  0           conv2d_12[0][0]
#                                                                  tf_op_layer_Reshape/shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_1 (Tenso [(1, None, None, 1,  0           tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile/multiples (Ten [(5,)]               0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_5 (TensorFl [(None, None, None,  0           conv2d_9[0][0]
#                                                                  tf_op_layer_Reshape_5/shape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_3 (Tenso [(1, None, None, 1,  0           tf_op_layer_ExpandDims_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile_1/multiples (T [(5,)]               0           tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_split (TensorFlowOp [(None, None, None,  0           tf_op_layer_Reshape[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile (TensorFlowOpL [(None, None, None,  0           tf_op_layer_ExpandDims_1[0][0]
#                                                                  tf_op_layer_Tile/multiples[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_split_1 (TensorFlow [(None, None, None,  0           tf_op_layer_Reshape_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile_1 (TensorFlowO [(None, None, None,  0           tf_op_layer_ExpandDims_3[0][0]
#                                                                  tf_op_layer_Tile_1/multiples[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid (TensorFlow [(None, None, None,  0           tf_op_layer_split[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast (TensorFlowOpL [(None, None, None,  0           tf_op_layer_Tile[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, None, None,  0           tf_op_layer_split[0][1]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_3 (TensorFl [(None, None, None,  0           tf_op_layer_split_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_1 (TensorFlowO [(None, None, None,  0           tf_op_layer_Tile_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, None, None,  0           tf_op_layer_split_1[0][1]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, None, None,  0           tf_op_layer_Sigmoid[0][0]
#                                                                  tf_op_layer_Cast[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None, None, None,  0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, None, None,  0           tf_op_layer_Sigmoid_3[0][0]
#                                                                  tf_op_layer_Cast_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_8 (TensorFlowOp [(None, None, None,  0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(None, None, None,  0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_4 (TensorFlowOp [(None, None, None,  0           tf_op_layer_Mul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_7 (TensorFlowOp [(None, None, None,  0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_9 (TensorFlowOp [(None, None, None,  0           tf_op_layer_Mul_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, None, None,  0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_Mul_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_1 (TensorFl [(None, None, None,  0           tf_op_layer_split[0][2]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_2 (TensorFl [(None, None, None,  0           tf_op_layer_split[0][3]
# __________________________________________________________________________________________________
# tf_op_layer_concat_3 (TensorFlo [(None, None, None,  0           tf_op_layer_Mul_7[0][0]
#                                                                  tf_op_layer_Mul_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_4 (TensorFl [(None, None, None,  0           tf_op_layer_split_1[0][2]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_5 (TensorFl [(None, None, None,  0           tf_op_layer_split_1[0][3]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, None, None,  0           tf_op_layer_concat_1[0][0]
#                                                                  tf_op_layer_Sigmoid_1[0][0]
#                                                                  tf_op_layer_Sigmoid_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_4 (TensorFlo [(None, None, None,  0           tf_op_layer_concat_3[0][0]
#                                                                  tf_op_layer_Sigmoid_4[0][0]
#                                                                  tf_op_layer_Sigmoid_5[0][0]
# ==================================================================================================
# Total params: 8,703,964
# Trainable params: 8,697,596
# Non-trainable params: 6,368
# __________________________________________________________________________________________________
# Train from Zero >>> yolov4
# epoch: 0 step:    2/51, lr:0.000002, giou_loss:  16.50, conf_loss: 425.23, prob_loss: 134.73, total_loss: 576.46
# epoch: 0 step:    3/51, lr:0.000003, giou_loss:  10.35, conf_loss: 383.81, prob_loss:  79.52, total_loss: 473.68
# epoch: 0 step:    4/51, lr:0.000004, giou_loss:   9.96, conf_loss: 380.50, prob_loss:  76.03, total_loss: 466.50
# epoch: 0 step:    5/51, lr:0.000005, giou_loss:   7.07, conf_loss: 375.38, prob_loss:  57.53, total_loss: 439.97
# epoch: 0 step:    6/51, lr:0.000006, giou_loss:  32.97, conf_loss: 371.68, prob_loss: 253.12, total_loss: 657.77
# epoch: 0 step:    7/51, lr:0.000007, giou_loss:  25.54, conf_loss: 367.45, prob_loss: 224.52, total_loss: 617.51
# epoch: 0 step:    8/51, lr:0.000008, giou_loss:   9.86, conf_loss: 369.19, prob_loss:  72.34, total_loss: 451.39
# epoch: 0 step:    9/51, lr:0.000009, giou_loss:  14.83, conf_loss: 365.90, prob_loss: 122.29, total_loss: 503.02
# epoch: 0 step:   10/51, lr:0.000010, giou_loss:  20.79, conf_loss: 363.25, prob_loss: 155.11, total_loss: 539.14
# epoch: 0 step:   11/51, lr:0.000011, giou_loss:   8.55, conf_loss: 362.09, prob_loss:  57.36, total_loss: 428.00
# epoch: 0 step:   12/51, lr:0.000012, giou_loss:   6.11, conf_loss: 357.06, prob_loss:  48.28, total_loss: 411.45
# epoch: 0 step:   13/51, lr:0.000013, giou_loss:  12.27, conf_loss: 353.50, prob_loss:  97.73, total_loss: 463.50
# epoch: 0 step:   14/51, lr:0.000014, giou_loss:  21.83, conf_loss: 350.01, prob_loss: 158.33, total_loss: 530.18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-bca54250c5ce> in <module>
#     188
#     189 if __name__ == '__main__':
# --> 190     main()
#
# <ipython-input-1-bca54250c5ce> in main()
#     150         # ======================================================= Train each epoch ========================================================
#     151
# --> 152         for image_data, target in trainset:  # Loop over train step (Num Batch)
#     153             results = train_step(image_data, target) # return global_steps, optimizer.lr, giou_loss, conf_loss, prob_loss, total_loss
#     154             cur_step = results[0] % steps_per_epoch  # เศษของ Global step หาร num batch จะได้ Current step ของ Epoch นั้นๆ
#
# C:\Module89_unicorn3\chessDetection\yolo_tiny_like_tf\dataset.py in __next__(self)
#     110                     if index >= self.num_samples: index -= self.num_samples
#     111                     annotation = self.annotations[index]
# --> 112                     image, bboxes = self.parse_annotation(annotation)
#     113                     try:
#     114                         label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes = self.preprocess_true_boxes(bboxes)
#
# C:\Module89_unicorn3\chessDetection\yolo_tiny_like_tf\dataset.py in parse_annotation(self, annotation, mAP)
#     211             return image, bboxes
#     212
# --> 213         image, bboxes = image_preprocess(np.copy(image), [self.input_sizes, self.input_sizes], np.copy(bboxes))
#     214         return image, bboxes
#     215
#
# C:\Module89_unicorn3\chessDetection\yolo_tiny_like_tf\utils.py in image_preprocess(image, target_size, gt_boxes)
#     127     dw, dh = (iw - nw) // 2, (ih-nh) // 2
#     128     image_paded[dh:nh+dh, dw:nw+dw, :] = image_resized
# --> 129     image_paded = image_paded / 255.
#     130
#     131     if gt_boxes is None:
#
# KeyboardInterrupt:
